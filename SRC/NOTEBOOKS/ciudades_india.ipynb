# %%
import graphviz as gv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from funciones_analisis import obtener_estadisticas
from funciones_analisis import convertir_notacion_india_numero_occidental

# %%
df_original=pd.read_csv(r"D:\Cursos\REPOSITORIOS\PARA ENTREGAR_EDA\SRC\DATA\DATASET ORIGINALES\Ciudades_pueblos_india.csv")

# %%
df_original.head()
# Out:
#    S. no. Name of City        State                                  Type  \
# 0       1       Mumbai  Maharashtra   Municipal Corporation / Corporation
# 1       2        Delhi        Delhi   Municipal Corporation / Corporation
# 2       3    Bengaluru    Karnataka   Municipal Corporation / Corporation
# 3       4    Ahmedabad      Gujarat  Municipal Corporation / Corporation.
# 4       5    Hyderabad    Telangana   Municipal Corporation / Corporation
#
#   Population (2011) Population class
# 0       1,35,97,924          Class I
# 1       1,10,07,835          Class I
# 2         84,25,970          Class I
# 3         72,08,200          Class I
# 4         68,09,970          Class I

# %%
df=pd.read_excel(r"D:\Cursos\REPOSITORIOS\PARA ENTREGAR_EDA\SRC\DATA\DATASETS MODIFICADOS\Ciudades_india_modificado.xlsx")

# %%
df
# Out:
#        Ciudades      Estados                      Tipo_area_urbana  \
# 0     Bengaluru    Karnataka   Municipal Corporation / Corporation
# 1     Ahmedabad      Gujarat  Municipal Corporation / Corporation.
# 2     Hyderabad    Telangana   Municipal Corporation / Corporation
# 3       Chennai   Tamil Nadu  Municipal Corporation / Corporation.
# 4       Kolkata  West Bengal   Municipal Corporation / Corporation
# ...         ...          ...                                   ...
# 1210        NaN          NaN                                   NaN
# 1211        NaN          NaN                                   NaN
# 1212        NaN          NaN                                   NaN
# 1213        NaN          NaN                                   NaN
# 1214        NaN          NaN                                   NaN
#
#      Clases_sociales  Numero_Occidental              Tipo_ciudad
# 0            Class I        842500970.0  Ciudades_metropolitanas
# 1            Class I        720800200.0  Ciudades_metropolitanas
# 2            Class I        680900970.0  Ciudades_metropolitanas
# 3            Class I        468100087.0  Ciudades_metropolitanas
# 4            Class I        448600679.0  Ciudades_metropolitanas
# ...              ...                ...                      ...
# 1210             NaN                NaN         Ciudades_menores
# 1211             NaN                NaN         Ciudades_menores
# 1212             NaN                NaN         Ciudades_menores
# 1213             NaN                NaN         Ciudades_menores
# 1214             NaN                NaN         Ciudades_menores
#
# [1215 rows x 6 columns]

# %%
df.to_excel(r"D:\Cursos\REPOSITORIOS\PARA ENTREGAR_EDA\SRC\DATA\DATASETS MODIFICADOS\Ciudades_india_modificado.xlsx", index = False)

# %%
df['Numero_Occidental'] = df["Population (2011)"].apply(convertir_notacion_india_numero_occidental)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Population (2011)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df['Numero_Occidental'] = df["Population (2011)"].apply(convertir_notacion_india_numero_occidental)
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\victo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Population (2011)'

# %%
df_ordenado= df.sort_values(by="Numero_Occidental", ascending=False, inplace =True)

# %%
def ciudades_india(numero):
 
    if numero > 10000000:
         return "Ciudades_metropolitanas"
    elif numero >1000000:
        return "Ciudades_principales"
    else:
        return "Ciudades_menores"

# %%
df["Tipo_ciudad"] = df['Numero_Occidental'].apply(ciudades_india)

# %%
df.rename(columns={"Name of City": "Ciudades"}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1215 entries, 0 to 1214
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Ciudades           1209 non-null   object
#  1   Estados            1209 non-null   object
#  2   Tipo_area_urbana   1206 non-null   object
#  3   Clases_sociales    661 non-null    object
#  4   Numero_Occidental  1209 non-null   float64
#  5   Tipo_ciudad        1215 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 57.1+ KB

# %%
#analizo el DF
resumen_analisis = obtener_estadisticas(df)
resumen_analisis
# Out:
#                   porcentaje_cardinalidad     Tipo        media  \
# Ciudades                            97.94   object           No
# Estados                               2.8   object           No
# Tipo_area_urbana                      2.8   object           No
# Clases_sociales                      0.41   object           No
# Numero_Occidental                   98.11  float64  16698184.52
# Tipo_ciudad                          0.25   object           No
#
#                                    moda          std                 var  \
# Ciudades                     Aurangabad           No                  No
# Estados                     Maharashtra           No                  No
# Tipo_area_urbana           Municipality           No                  No
# Clases_sociales                 Class I           No                  No
# Numero_Occidental                    No  51754997.92  2678579809533306.0
# Tipo_ciudad        Ciudades_principales           No                  No
#
#                           Q1    mediana          Q3           Categoria  \
# Ciudades                  No         No          No  categorica ordinal
# Estados                   No         No          No  categorica ordinal
# Tipo_area_urbana          No         No          No  categorica ordinal
# Clases_sociales           No         No          No  categorica ordinal
# Numero_Occidental  2900613.0  5000131.0  10600444.0   numerica continua
# Tipo_ciudad               No         No          No  categorica ordinal
#
#                   porcentaje_NaN
# Ciudades                    0.49
# Estados                     0.49
# Tipo_area_urbana            0.74
# Clases_sociales             45.6
# Numero_Occidental           0.49
# Tipo_ciudad                  0.0

# %%
#me traigo mi dataframe , para sacar la lista de ciudades origen de los ataques con este dataframe
df_eda=pd.read_excel(r"D:\Cursos\REPOSITORIOS\PARA ENTREGAR_EDA\SRC\DATA\DATASETS MODIFICADOS\ciber_modificado.xlsx")

# %%
df_eda.head(5)
# Out:
#            Fecha_hora       IP Origen       Destino IP  Puerto_origen  \
# 0 2023-05-30 06:33:58   103.216.15.12     84.9.164.252          31225
# 1 2020-08-26 07:08:30  78.199.217.198   66.191.137.154          17245
# 2 2022-11-13 08:23:25    63.79.210.48    198.219.82.17          16811
# 3 2023-07-02 10:38:46   163.42.196.10  101.228.192.255          20018
# 4 2023-07-16 13:11:07   71.166.185.76  189.243.174.238           6131
#
#    Puerto_destino Protocolo  Longitud_paquete Tipo_paquete  Tipo  \
# 0           17616      ICMP               503         Data  HTTP
# 1           48166      ICMP              1174         Data  HTTP
# 2           53600       UDP               306      Control  HTTP
# 3           32534       UDP               385         Data  HTTP
# 4           26646       TCP              1462         Data   DNS
#
#                                     Datos_carga_util  ...     Firma_ataque  \
# 0  Qui natus odio asperiores nam. Optio nobis ius...  ...  Known Pattern B
# 1  Aperiam quos modi officiis veritatis rem. Omni...  ...  Known Pattern A
# 2  Perferendis sapiente vitae soluta. Hic delectu...  ...  Known Pattern B
# 3  Totam maxime beatae expedita explicabo porro l...  ...  Known Pattern B
# 4  Odit nesciunt dolorem nisi iste iusto. Animi v...  ...  Known Pattern B
#
#    respuesta_tomada Nivel_severidad Informacion_usuario  \
# 0            Logged             Low       Reyansh Dugal
# 1           Blocked             Low          Sumer Rana
# 2           Ignored             Low        Himmat Karpe
# 3           Blocked          Medium          Fateh Kibe
# 4           Blocked             Low        Dhanush Chad
#
#                              Informacion_dispositivo Segmento_red  \
# 0  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...    Segment A
# 1  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...    Segment B
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...    Segment C
# 3  Mozilla/5.0 (Macintosh; PPC Mac OS X 10_11_5; ...    Segment B
# 4  Mozilla/5.0 (compatible; MSIE 5.0; Windows NT ...    Segment C
#
#   Datos_geolocalizacion Información_proxy Registros_cortafuegos  \
# 0    Jamshedpur, Sikkim      150.9.97.135              Log Data
# 1    Bilaspur, Nagaland               NaN              Log Data
# 2     Bokaro, Rajasthan    114.133.48.179              Log Data
# 3    Jaunpur, Rajasthan               NaN                   NaN
# 4    Anantapur, Tripura     149.6.110.119                   NaN
#
#   Fuente_registro
# 0          Server
# 1        Firewall
# 2        Firewall
# 3        Firewall
# 4        Firewall
#
# [5 rows x 26 columns]

# %%
print(len(df_eda.Datos_geolocalizacion.unique()))
# Out:
# 8723

# %%
df["Clases_sociales"].value_counts()
# Out:
# Clases_sociales
# Class I      254
# Class III    205
# Class II     183
# Class IV      12
# Class V        7
# Name: count, dtype: int64

# %%
# Contar las ocurrencias de cada combinación de 'Ciudades' y 'Estados' en ambos DataFrames
num_df_eda = df_eda.groupby(['Ciudades', 'Estados']).size().reset_index(name='Conteo_eda')# agrupamos por ciudades y estados contando con size por valores unicos, y agrupando el resultado
# en la columna dela variable name
num_df = df.groupby(['Ciudades', 'Estados']).size().reset_index(name='Conteo_df')

# Fusionar los resultados en un nuevo DataFrame
resultado = pd.merge(num_df_eda, num_df, on=['Ciudades', 'Estados'], how='outer').fillna(0)

# Calcular la suma total de ocurrencias
resultado['Total'] = resultado['Conteo_eda'] + resultado['Conteo_df']

# Filtrar las filas donde hay coincidencias (donde Total > 0)
df_conteo_ciudades = resultado[resultado['Total'] > 0]

# Mostrar el resultado
df_conteo_ciudades.head(1)
# Out:
#   Ciudades         Estados  Conteo_eda  Conteo_df  Total
# 0    Adoni  Andhra Pradesh         4.0        1.0    5.0

# %%
print(len(num_df_eda))
# Out:
# 8723

# %%
print(len(num_df))
# Out:
# 1205

# %%
resultado = df_conteo_ciudades.loc[(df_conteo_ciudades["Conteo_eda"] >= 1) & (df_conteo_ciudades["Conteo_df"] >= 1)]

print(len(resultado))
resultado
# Out:
# 197
#            Ciudades         Estados  Conteo_eda  Conteo_df  Total
# 0             Adoni  Andhra Pradesh         4.0        1.0    5.0
# 52         Agartala         Tripura         3.0        1.0    4.0
# 81             Agra   Uttar Pradesh         6.0        1.0    7.0
# 90        Ahmedabad         Gujarat         5.0        1.0    6.0
# 125      Ahmednagar     Maharashtra         4.0        1.0    5.0
# ...             ...             ...         ...        ...    ...
# 8578        Vellore      Tamil Nadu         5.0        1.0    6.0
# 8612     Vijayawada  Andhra Pradesh         2.0        1.0    3.0
# 8640  Visakhapatnam  Andhra Pradesh         7.0        1.0    8.0
# 8690       Warangal       Telangana         6.0        1.0    7.0
# 8702    Yamunanagar         Haryana         2.0        1.0    3.0
#
# [197 rows x 5 columns]

# %%
df_eda.head(1)
# Out:
#            Fecha_hora      IP Origen    Destino IP  Puerto_origen  \
# 0 2023-05-30 06:33:58  103.216.15.12  84.9.164.252          31225
#
#    Puerto_destino Protocolo  Longitud_paquete Tipo_paquete  Tipo  \
# 0           17616      ICMP               503         Data  HTTP
#
#                                     Datos_carga_util  ...     Firma_ataque  \
# 0  Qui natus odio asperiores nam. Optio nobis ius...  ...  Known Pattern B
#
#    respuesta_tomada Nivel_severidad Informacion_usuario  \
# 0            Logged             Low       Reyansh Dugal
#
#                              Informacion_dispositivo Segmento_red  \
# 0  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...    Segment A
#
#   Datos_geolocalizacion Información_proxy Registros_cortafuegos  \
# 0    Jamshedpur, Sikkim      150.9.97.135              Log Data
#
#   Fuente_registro
# 0          Server
#
# [1 rows x 26 columns]

# %%
df
# Out:
#        Ciudades      Estados                      Tipo_area_urbana  \
# 0     Bengaluru    Karnataka   Municipal Corporation / Corporation
# 1     Ahmedabad      Gujarat  Municipal Corporation / Corporation.
# 2     Hyderabad    Telangana   Municipal Corporation / Corporation
# 3       Chennai   Tamil Nadu  Municipal Corporation / Corporation.
# 4       Kolkata  West Bengal   Municipal Corporation / Corporation
# ...         ...          ...                                   ...
# 1210        NaN          NaN                                   NaN
# 1211        NaN          NaN                                   NaN
# 1212        NaN          NaN                                   NaN
# 1213        NaN          NaN                                   NaN
# 1214        NaN          NaN                                   NaN
#
#      Clases_sociales  Numero_Occidental              Tipo_ciudad
# 0            Class I        842500970.0  Ciudades_metropolitanas
# 1            Class I        720800200.0  Ciudades_metropolitanas
# 2            Class I        680900970.0  Ciudades_metropolitanas
# 3            Class I        468100087.0  Ciudades_metropolitanas
# 4            Class I        448600679.0  Ciudades_metropolitanas
# ...              ...                ...                      ...
# 1210             NaN                NaN         Ciudades_menores
# 1211             NaN                NaN         Ciudades_menores
# 1212             NaN                NaN         Ciudades_menores
# 1213             NaN                NaN         Ciudades_menores
# 1214             NaN                NaN         Ciudades_menores
#
# [1215 rows x 6 columns]

# %%
# Crear un DataFrame con la comparación de 'Ciudades' y 'Estados'
resultado_2 = pd.merge(df[['Ciudades', 'Estados', 'Tipo_ciudad']], df_eda[['Ciudades', 'Estados']], on=['Ciudades', 'Estados'], how='outer', suffixes=('_df1', '_df2'))

# Mostrar el resultado
resultado_2
# Out:
#         Ciudades        Estados              Tipo_ciudad
# 0      Bengaluru      Karnataka  Ciudades_metropolitanas
# 1      Ahmedabad        Gujarat  Ciudades_metropolitanas
# 2      Ahmedabad        Gujarat  Ciudades_metropolitanas
# 3      Ahmedabad        Gujarat  Ciudades_metropolitanas
# 4      Ahmedabad        Gujarat  Ciudades_metropolitanas
# ...          ...            ...                      ...
# 41013     Purnia  Uttar Pradesh                      NaN
# 41014    Cuttack         Sikkim                      NaN
# 41015   Vadodara      Meghalaya                      NaN
# 41016    Cuttack      Jharkhand                      NaN
# 41017     Nagpur         Punjab                      NaN
#
# [41018 rows x 3 columns]

# %%
resultado_2.value_counts()
# Out:
# Ciudades      Estados        Tipo_ciudad
# Aurangabad    Bihar          Ciudades_metropolitanas    10
# Hyderabad     Telangana      Ciudades_metropolitanas    10
# Munger        Bihar          Ciudades_metropolitanas    10
# Jodhpur       Rajasthan      Ciudades_metropolitanas    10
# Meerut        Uttar Pradesh  Ciudades_metropolitanas     9
#                                                         ..
# Nadbai        Rajasthan      Ciudades_principales        1
# Nagaon        Assam          Ciudades_metropolitanas     1
# Nagapattinam  Tamil Nadu     Ciudades_metropolitanas     1
# Nagar         Rajasthan      Ciudades_principales        1
# Zunheboto     Nagaland       Ciudades_principales        1
# Name: count, Length: 1207, dtype: int64

# %%
ciudades_importantes= ["Delhi", "Mumbai","Kolkata","Chennai","Bengaluru","Hyderabad","Ahmedabad","Pune","Surat" ]

# Filtrar el DataFrame resultado para incluir solo las ciudades de interés
ciudades_interes = resultado_2[resultado_2['Ciudades'].isin(ciudades_importantes)]

# Obtener el conteo de cada ciudad de interés
conteo_ciudades_interes = ciudades_interes['Ciudades'].value_counts()


conteo_ciudades_interes
# Out:
# Ciudades
# Hyderabad    129
# Ahmedabad    125
# Delhi        121
# Mumbai       121
# Kolkata      116
# Chennai      115
# Pune         112
# Surat        109
# Bengaluru      1
# Name: count, dtype: int64

# %% [markdown]
# La India tien un total de 28 Estados y un total de 7908 ciudades en total. En mi df_eda aparecen los 28 estados, y 316 ciudades que muchas se repiten, ed decir ciudades de todos los estados. Ademas las ciudades mas importantes de la India son Delhi, Mumbai,Kolkata , Chennai , Bengaluru , Hyderabad , Ahmedabad , Pune y Surat , las cuales aparecen en mi df_eda un numero muy elevado de veces, euivalentes a numero de ataques que tiene origen las 10 ciudades mas importantes de la india.
